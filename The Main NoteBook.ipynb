# %% [markdown]
# # The Data Legend (my capstone)
#
# ## The main notebook
#
# #### Author: Hussain AlAttas (RUH)
#
# ---
# **In this notebook, I explore the data, clean it, data engineer it, and perform a baseline accuracy.**

# %%
# Importing libraries
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, cross_val_score
import seaborn as sns
# %matplotlib inline

# %%
# Loading the data
LOL = pd.read_csv('./LeagueofLegends.csv').dropna() # Dropping the unnecessary small amount of null values
Dictionary_df = pd.read_csv('./_columns.csv') # The DataFrame that explains the columns in the first set

# %%
# Creating a dataframe for only the players' usernames for later usage
Players_LOL_df = LOL[['blueTop','blueJungle','blueMiddle','blueADC','blueSupport',
                         'redTop','redJungle','redMiddle','redADC','redSupport']]

cols_to_remove = ['Address','blueTeamTag','redTeamTag','golddiff','goldblue',
                  'goldred','goldblueTop', 'goldblueJungle','goldblueMiddle',
                  'goldblueADC','goldblueSupport','goldredTop','goldredMiddle',
                  'goldredSupport','bInhibs','bDragons','bBarons','bHeralds',
                  'rKills', 'rTowers','rInhibs','rDragons','rBarons','rHeralds',
                  'blueBans', 'redBans', 'goldredJungle', 'goldredADC', 'bTowers',
                  'bKills', 'rResult']
LOL.drop(cols_to_remove,axis=1, inplace=True) # Removing columns that are unnecessary

# %%
# Removing the same columns from the dictionary dataframe
Dictionary_df.set_index('ColumnName').drop(cols_to_remove, inplace=True)

# %%
# Writing a function for doing the basic EDA checks
def Basic_eda_check(data):
    print('\n')
    print('This is the shape of the data', data.shape)
    display(data.head())
    display(data.tail())
    print('\n\n')
    print('There is {} null values'.format(data.isnull().sum().sum()))
    print('\n\n')
    display(data.describe().T)
    print('\n\n')
    data.info()
    print('\n\n')
    for x in data.columns:
        print(x)
        print(data[x].value_counts(dropna=False))
        print('\n\n\n\n')

# %%
Basic_eda_check(LOL) # Checking the set
# Out:
# This is the shape of the data (7582, 26)
#   League  Year  Season    Type  bResult  gamelength  blueTop blueTopChamp  \
# 0  NALCS  2015  Spring  Season        1          40    Dyrus       Irelia
# 1  NALCS  2015  Spring  Season        0          38     Cris         Gnar
# 2  NALCS  2015  Spring  Season        1          40  Flaresz     Renekton
# 3  NALCS  2015  Spring  Season        0          41     Rhux       Irelia
# 4  NALCS  2015  Spring  Season        1          35    Benny         Gnar
#
#    blueJungle blueJungleChamp       ...             redTop redTopChamp  \
# 0    Santorin          RekSai       ...              Balls        Gnar
# 1     Impaler          Rengar       ...              Gamsu      Irelia
# 2  ShorterACE          Rengar       ...           Hauntzer        Sion
# 3        Rush        JarvanIV       ...               Quas        Gnar
# 4     Xmithie        JarvanIV       ...        CaliTrlolz8        Sion
#
#       redJungle redJungleChamp redMiddle redMiddleChamp        redADC  \
# 0        Meteos          Elise       Hai           Fizz        Sneaky
# 1       Crumbzz       JarvanIV  Shiphtur           Azir        CoreJJ
# 2  Saintvicious         LeeSin     Keane           Azir           Cop
# 3    IWDominate           Nunu     Fenix           Lulu         KEITH
# 4     Porpoise8         RekSai  Slooshi8           Lulu  Maplestreet8
#
#   redADCChamp   redSupport redSupportChamp
# 0       Sivir  LemonNation          Thresh
# 1       Corki      KiWiKiD           Annie
# 2       Corki   BunnyFuFuu           Janna
# 3      KogMaw      Xpecial           Janna
# 4       Corki        Dodo8           Annie
#
# [5 rows x 26 columns]
#      League  Year  Season    Type  bResult  gamelength   blueTop blueTopChamp  \
# 7615    TCL  2018  Spring  Season        0          34    Elwind      Camille
# 7616    TCL  2018  Spring  Season        0          39      Rare        Nasus
# 7617    OPL  2018  Spring  Season        0          24  Praedyth      Camille
# 7618    OPL  2018  Spring  Season        1          35     Ceres         Ornn
# 7619    OPL  2018  Spring  Season        0          42   Papryze    Gangplank
#
#      blueJungle blueJungleChamp       ...             redTop redTopChamp  \
# 7615     Mojito        JarvanIV       ...        fabFabulous     Chogath
# 7616     Viking          Khazix       ...           Marshall     Chogath
# 7617      Juves        JarvanIV       ...            Chippys   Gangplank
# 7618      Sybol          Khazix       ...            Papryze   Gangplank
# 7619     Swathe             Zac       ...              Ceres        Ornn
#
#      redJungle redJungleChamp redMiddle redMiddleChamp    redADC redADCChamp  \
# 7615  Stomaged        XinZhao       GBM         Veigar   Zeitnot       Xayah
# 7616     KaKAO          Ivern    Lucete           Ryze  Ruvelius     Caitlyn
# 7617   Praelus        Evelynn    Triple       Malzahar      k1ng      Ezreal
# 7618    Swathe       JarvanIV      Shok         Veigar       Low       Sivir
# 7619     Sybol       JarvanIV    Claire       Malzahar      Raid       Vayne
#
#       redSupport redSupportChamp
# 7615  SnowFlower           Rakan
# 7616      Japone           Braum
# 7617     Cupcake           Taric
# 7618     Tilting           Janna
# 7619       Decoy           Braum
#
# [5 rows x 26 columns]
# There is 0 null values
#              count         mean       std     min     25%     50%     75%  \
# Year        7582.0  2016.282511  0.849968  2014.0  2016.0  2016.0  2017.0
# bResult     7582.0     0.544315  0.498065     0.0     0.0     1.0     1.0
# gamelength  7582.0    37.009101  7.986554    17.0    31.0    36.0    41.0
#
#                max
# Year        2018.0
# bResult        1.0
# gamelength    95.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7582 entries, 0 to 7619
# Data columns (total 26 columns):
# League              7582 non-null object
# Year                7582 non-null int64
# Season              7582 non-null object
# Type                7582 non-null object
# bResult             7582 non-null int64
# gamelength          7582 non-null int64
# blueTop             7582 non-null object
# blueTopChamp        7582 non-null object
# blueJungle          7582 non-null object
# blueJungleChamp     7582 non-null object
# blueMiddle          7582 non-null object
# blueMiddleChamp     7582 non-null object
# blueADC             7582 non-null object
# blueADCChamp        7582 non-null object
# blueSupport         7582 non-null object
# blueSupportChamp    7582 non-null object
# redTop              7582 non-null object
# redTopChamp         7582 non-null object
# redJungle           7582 non-null object
# redJungleChamp      7582 non-null object
# redMiddle           7582 non-null object
# redMiddleChamp      7582 non-null object
# redADC              7582 non-null object
# redADCChamp         7582 non-null object
# redSupport          7582 non-null object
# redSupportChamp     7582 non-null object
# dtypes: int64(3), object(23)
# memory usage: 1.6+ MB
#
#
#
# League
# LCK      1445
# NALCS    1272
# EULCS    1099
# LMS       777
# TCL       653
# OPL       458
# WC        308
# CBLoL     301
# LCL       281
# LLN       242
# LJL       221
# CLS       175
# IEM       138
# MSI       111
# RR        101
# Name: League, dtype: int64
#
#
#
#
#
# Year
# 2017    3311
# 2016    2457
# 2015    1495
# 2018     241
# 2014      78
# Name: Year, dtype: int64
#
#
#
#
#
# Season
# Summer    4071
# Spring    3511
# Name: Season, dtype: int64
#
#
#
#
#
# Type
# Season           5615
# Playoffs          775
# International     658
# Promotion         391
# Regional          143
# Name: Type, dtype: int64
#
#
#
#
#
# bResult
# 1    4127
# 0    3455
# Name: bResult, dtype: int64
#
#
#
#
#
# gamelength
# 34    434
# 35    405
# 32    397
# 33    389
# 31    383
# 30    376
# 36    375
# 37    364
# 38    359
# 39    354
# 40    333
# 29    304
# 41    295
# 42    261
# 28    260
# 43    230
# 27    223
# 44    206
# 45    183
# 26    162
# 46    136
# 47    134
# 25    105
# 48    104
# 49     92
# 24     92
# 50     85
# 51     73
# 52     56
# 53     46
#      ...
# 55     37
# 23     36
# 57     35
# 22     26
# 58     20
# 61     15
# 59     14
# 21     13
# 62     11
# 60     11
# 63     10
# 20      7
# 72      6
# 64      6
# 67      5
# 66      5
# 69      4
# 65      4
# 68      4
# 70      3
# 71      3
# 18      2
# 81      2
# 17      1
# 77      1
# 75      1
# 74      1
# 78      1
# 19      1
# 95      1
# Name: gamelength, Length: 62, dtype: int64
#
#
#
#
#
# blueTop
# Smeb           178
# Ssumday        169
# CuVee          167
# Odoamne        149
# Hauntzer       137
# Huni           126
# Ziv            124
# Darshan        124
# Vizicsacsi     120
# Impact         120
# Balls          116
# MaRin          116
# Duke           104
# Lourlo         103
# sOAZ           103
# Seraph          97
# Elwind          93
# ikssu           91
# MMD             90
# Expect          90
# Thaldrin        87
# TrAce           84
# Crazy           81
# Morning         78
# zig             78
# Cabochard       78
# Shy             73
# ADD             73
# Expession       69
# Swip3rR         65
#               ...
# Tonington        1
# Send0o           1
# Mysterious       1
# Rippii           1
# brTT RX          1
# Idyiom           1
# Never            1
# Aoi Haru         1
# ssumday          1
# Benny            1
# LukasNegro       1
# HanShao          1
# TheSoloKing      1
# Verto            1
# BonziN           1
# DarkBlight       1
# Astarore         1
# ZvenE            1
# Survivalone      1
# i KeNNy u        1
# K3nSt3r          1
# Eryon            1
# AJun             1
# Part             1
# Leko             1
# Zeclipse         1
# Artaphernes      1
# indra            1
# paradise         1
# Miracle          1
# Name: blueTop, Length: 319, dtype: int64
#
#
#
#
#
# blueTopChamp
# Maokai         816
# Shen           652
# Gnar           624
# Rumble         571
# Nautilus       400
# Poppy          386
# Trundle        323
# Renekton       306
# Fiora          246
# JarvanIV       237
# Camille        221
# Gragas         216
# Irelia         212
# Gangplank      212
# Ekko           200
# Kennen         160
# Jayce          146
# Hecarim        134
# Chogath        123
# Kled           116
# Ryze           113
# Jax            111
# Lulu            98
# Fizz            95
# Galio           88
# Lissandra       83
# Malphite        71
# Sion            59
# TahmKench       54
# Swain           46
#               ...
# Sejuani          7
# Akali            5
# Alistar          5
# Yorick           5
# RekSai           4
# Azir             4
# Nidalee          4
# Nasus            3
# LeeSin           3
# Pantheon         3
# Malzahar         3
# Teemo            2
# Rengar           2
# Zac              2
# Mordekaiser      2
# Nocturne         2
# Urgot            2
# Talon            2
# Katarina         1
# Warwick          1
# Nunu             1
# Taliyah          1
# Khazix           1
# Bard             1
# Zed              1
# Blitzcrank       1
# Karma            1
# Diana            1
# XinZhao          1
# Varus            1
# Name: blueTopChamp, Length: 78, dtype: int64
#
#
#
#
#
# blueJungle
# Score          175
# Ambition       152
# Xmithie        149
# Svenskeren     141
# Reignover      134
# Jankos         132
# Karsa          127
# Trick          118
# Mountain       113
# Spirit         112
# Peanut         111
# LirA            98
# Chaser          96
# Stomaged        95
# Dardoch         89
# Meteos          80
# Trashy          79
# Amazing         79
# Move            78
# Moon            75
# Taizan          75
# Bengi           74
# Beyond          73
# Maxlore         72
# Bless           70
# Wisdom          67
# Juves           67
# Santorin        66
# Spookz          65
# Blank           64
#               ...
# beibei           1
# Pride            1
# Muscle           1
# HiBon            1
# Doxy             1
# VII              1
# Lilac            1
# DanDayn          1
# Loulex           1
# Yampi            1
# Mess             1
# xSojin           1
# SoulStrikes      1
# Rokenia          1
# Auspexa          1
# t4nk             1
# Crimson          1
# Duxen            1
# Phantiks         1
# iSeNN            1
# LoveLing         1
# AnDa             1
# Mister           1
# Akira            1
# MiMo             1
# betty            1
# Comeback         1
# Smurph           1
# Halpern          1
# Shaunz           1
# Name: blueJungle, Length: 346, dtype: int64
#
#
#
#
#
# blueJungleChamp
# RekSai          1114
# Elise           1055
# Gragas           986
# LeeSin           655
# Graves           590
# Khazix           484
# Nidalee          420
# Rengar           353
# JarvanIV         334
# Sejuani          279
# Zac              198
# Kindred          196
# Olaf             172
# Ivern            105
# Evelynn           83
# Hecarim           78
# Nunu              75
# Maokai            74
# Ekko              54
# Vi                32
# Warwick           30
# Chogath           24
# Kayn              22
# Rumble            20
# Nocturne          16
# Shyvana           14
# Udyr              14
# Poppy             12
# Pantheon          10
# Jax               10
# Rammus             7
# Amumu              6
# Skarner            6
# Camille            6
# Nautilus           6
# Trundle            5
# DrMundo            5
# Shaco              5
# Sion               3
# Karthus            2
# Lulu               2
# Bard               2
# Syndra             2
# XinZhao            2
# Fizz               2
# Darius             1
# Malphite           1
# Shen               1
# Mordekaiser        1
# FiddleSticks       1
# Draven             1
# Illaoi             1
# Kassadin           1
# Alistar            1
# Fiddlesticks       1
# Ezreal             1
# Leblanc            1
# Name: blueJungleChamp, dtype: int64
#
#
#
#
#
# blueMiddle
# Faker           177
# Kuro            165
# Crown           152
# Ryu             146
# Bjergsen        146
# Febiven         146
# Maple           132
# Pobelter        125
# PowerOfEvil     125
# Huhi            123
# Mickey          120
# Keane           118
# Jensen          110
# Perkz           110
# Frozen          101
# Froggen         101
# Naru             97
# Kuzan            94
# Betsy            87
# Hai              85
# Fly              84
# Apex             80
# Exileh           79
# Coco             79
# Tempt            79
# Ian              73
# GBM              73
# Sencux           71
# Edge             70
# FoFo             70
#                ...
# Tucake            1
# MapleSnow         1
# Takefuned         1
# Arcsecond         1
# BoBo              1
# BDD               1
# Ryavka            1
# Lucete            1
# Rakin             1
# ShLaYa            1
# Easy              1
# PAinEvil          1
# Julaxe            1
# Abou222           1
# Rain              1
# Leonard           1
# do it             1
# Fate              1
# Justice           1
# Emp               1
# huhi              1
# Sayn              1
# Dumbledoge        1
# Mueki             1
# tei               1
# Misteryous        1
# Heavenstrike      1
# Ringer            1
# Gluppy            1
# Baxauer           1
# Name: blueMiddle, Length: 322, dtype: int64
#
#
#
#
#
# blueMiddleChamp
# Orianna         643
# Viktor          609
# Syndra          526
# Azir            481
# Corki           446
# Leblanc         417
# Cassiopeia      391
# Taliyah         388
# Ryze            363
# Ahri            334
# Vladimir        309
# Lulu            225
# Lissandra       199
# Zed             183
# Jayce           180
# Kassadin        167
# Galio           154
# Karma           153
# TwistedFate     152
# Malzahar        131
# Varus           115
# Ekko             97
# Zilean           83
# Lucian           77
# Ezreal           69
# Xerath           65
# Anivia           54
# Talon            52
# Gangplank        44
# Lux              43
#                ...
# KogMaw           14
# Urgot            13
# Morgana          11
# Veigar            9
# Nautilus          8
# JarvanIV          7
# Quinn             7
# Irelia            5
# Jhin              4
# Rumble            4
# Graves            3
# Nidalee           3
# Pantheon          3
# Kennen            3
# MasterYi          2
# Kayn              2
# Kayle             2
# Heimerdinger      2
# Riven             2
# Fiora             2
# LeeSin            1
# Camille           1
# Akali             1
# Mordekaiser       1
# Teemo             1
# Nunu              1
# Draven            1
# Tristana          1
# Kindred           1
# Elise             1
# Name: blueMiddleChamp, Length: 71, dtype: int64
#
#
#
#
#
# blueADC
# Bang            195
# Arrow           168
# PraY            167
# Sneaky          153
# Rekkles         140
# WildTurtle      132
# Sangyoon        129
# Doublelift      125
# Stixxay         123
# Apollo          123
# Zven            115
# Kramer          108
# Nuclear         101
# Ruler            99
# Hjarnan          93
# Altec            91
# Piglet           91
# Deft             87
# Dee              86
# Steeelback       85
# Zeitnot          84
# Keith            81
# Madness          79
# BeBe             76
# AN               75
# HolyPhoenix      74
# Pilot            74
# MaHa             72
# Kobbe            69
# Fury             68
#                ...
# Straawbella       1
# Stierlitz         1
# Breaker           1
# Deee              1
# Wako              1
# M17Dee            1
# Frost             1
# OB5               1
# XDSMILEY          1
# J1mmy             1
# 0hq               1
# I Am The IRS      1
# Nono              1
# Paragon           1
# nororin           1
# Kz                1
# cop               1
# Crykee            1
# ZeroZeroYon       1
# SirAlphaQ         1
# K                 1
# Hobbler           1
# Bomb              1
# Moopz             1
# Achu              1
# Paradise          1
# The Foxz          1
# aphromoo          1
# dan               1
# Rakin             1
# Name: blueADC, Length: 344, dtype: int64
#
#
#
#
#
# blueADCChamp
# Lucian          793
# Sivir           780
# Ashe            751
# Kalista         701
# Jhin            674
# Varus           655
# Ezreal          651
# Caitlyn         582
# Tristana        438
# Corki           378
# KogMaw          276
# Xayah           256
# Jinx            116
# Twitch          113
# Vayne           112
# Graves          111
# MissFortune      49
# Ziggs            35
# Draven           33
# Urgot            32
# Kennen           31
# Mordekaiser       7
# Irelia            1
# Quinn             1
# Heimerdinger      1
# Alistar           1
# Blitzcrank        1
# Karma             1
# Janna             1
# Viktor            1
# Name: blueADCChamp, dtype: int64
#
#
#
#
#
# blueSupport
# Wolf           185
# GorillA        174
# aphromoo       150
# Chei           124
# Hylissang      123
# Olleh          121
# SnowFlower     121
# Albis          115
# Adrian         112
# Xpecial        107
# LemonNation    106
# MadLife        101
# Matt            98
# Smoothie        98
# mithy           95
# Vander          92
# Jay             90
# Dreamer         90
# Mata            89
# Biofrost        89
# IgNar           87
# Hakuho          86
# Wraith          85
# Gate            81
# CoreJJ          80
# Pure            79
# Dumbledoge      78
# Key             78
# Max             76
# TusiN           76
#               ...
# Ken              1
# Indivisible      1
# k1               1
# Terette          1
# Chunkyfresh      1
# Blumigan         1
# Mallek           1
# Tierwulf         1
# Breaker          1
# Ralara           1
# Nevan            1
# Nukeduck         1
# Cejlon           1
# Whyin            1
# Primoo           1
# Beni             1
# Straawbella      1
# Bluz0r           1
# Angelas          1
# Sweetr           1
# Promisq          1
# SimSin           1
# Altec            1
# Athena           1
# Vioreleeee       1
# Lounet           1
# Wei              1
# Bischu           1
# Stuntopolis      1
# Hanjaro          1
# Name: blueSupport, Length: 344, dtype: int64
#
#
#
#
#
# blueSupportChamp
# Braum           1064
# Thresh           951
# Alistar          763
# Karma            637
# Janna            421
# Lulu             401
# Zyra             376
# TahmKench        368
# Bard             340
# Nami             307
# Morgana          287
# Trundle          239
# Malzahar         199
# Rakan            190
# Nautilus         181
# Taric            150
# Annie            129
# Blitzcrank        83
# Soraka            78
# Leona             77
# MissFortune       62
# Shen              41
# Kennen            38
# Brand             30
# Poppy             26
# Sona              24
# Zilean            21
# Camille           17
# Veigar            10
# Galio              9
# Velkoz             7
# Gragas             7
# Ornn               6
# Maokai             5
# Sejuani            4
# Lux                4
# LeeSin             3
# Kayle              3
# Lissandra          3
# Sion               3
# Garen              2
# Fiddlesticks       2
# Ashe               2
# Ahri               1
# Irelia             1
# Nunu               1
# DrMundo            1
# Taliyah            1
# Zac                1
# Kalista            1
# Malphite           1
# Syndra             1
# Elise              1
# Evelynn            1
# Cassiopeia         1
# Name: blueSupportChamp, dtype: int64
#
#
#
#
#
# redTop
# CuVee            157
# Smeb             156
# Hauntzer         156
# Ssumday          149
# Vizicsacsi       141
# Impact           129
# Huni             127
# Duke             120
# Odoamne          115
# Ziv              115
# Darshan          113
# MaRin            107
# Seraph           105
# Balls            100
# TrAce             98
# ikssu             96
# Lourlo            95
# Cabochard         89
# MMD               89
# sOAZ              88
# Morning           88
# Elwind            86
# Crazy             86
# zig               84
# Thaldrin          80
# ADD               78
# Shy               78
# Expect            76
# Wunder            73
# Flame             72
#                 ...
# Mysterious         1
# Moracras           1
# InnoX              1
# Never              1
# Aoi Haru           1
# Tonington          1
# WhiteKnight        1
# exciting           1
# Resu               1
# LukasNegro         1
# Renrin             1
# DarkBlight         1
# Leko               1
# Verto              1
# Cejlon             1
# AJun               1
# Ever Crazy         1
# Gate               1
# MaybeNickName      1
# brTT RX            1
# Kaigu              1
# Artaphernes        1
# Xiyang             1
# paradise           1
# TheSoloKing        1
# HanShao            1
# Kulo               1
# DDD                1
# Eryon              1
# Babunia            1
# Name: redTop, Length: 324, dtype: int64
#
#
#
#
#
# redTopChamp
# Maokai          868
# Gnar            664
# Shen            603
# Rumble          526
# Nautilus        396
# Poppy           383
# Renekton        326
# Trundle         320
# Fiora           284
# JarvanIV        232
# Irelia          226
# Gragas          226
# Ekko            221
# Gangplank       213
# Camille         166
# Kennen          149
# Kled            133
# Hecarim         128
# Chogath         115
# Jayce           111
# Fizz            108
# Lissandra        98
# Jax              96
# Lulu             83
# Malphite         75
# Galio            75
# Ryze             69
# DrMundo          52
# Sion             51
# TahmKench        48
#                ...
# Aatrox            6
# Urgot             5
# Pantheon          5
# Zac               5
# Nasus             5
# Rengar            4
# Mordekaiser       4
# RekSai            4
# Yorick            3
# Zed               3
# Warwick           2
# Teemo             2
# Khazix            2
# Azir              2
# Talon             2
# Taliyah           2
# LeeSin            2
# Karma             2
# Malzahar          2
# Tryndamere        1
# XinZhao           1
# MasterYi          1
# Diana             1
# Kayn              1
# Heimerdinger      1
# Shaco             1
# MonkeyKing        1
# Annie             1
# Ashe              1
# Viktor            1
# Name: redTopChamp, Length: 81, dtype: int64
#
#
#
#
#
# redJungle
# Score         154
# Svenskeren    150
# Ambition      142
# Xmithie       135
# Karsa         124
# Reignover     120
# Peanut        113
# Jankos        111
# Trick         109
# LirA          106
# Mountain      104
# Chaser        102
# Spirit        102
# Stomaged      101
# Trashy         99
# Dardoch        89
# Amazing        87
# Santorin       86
# Blank          80
# Xerxe          79
# Beyond         78
# Bless          77
# Move           77
# Meteos         71
# Juves          67
# Taizan         67
# Contractz      67
# Carbon         65
# Bengi          65
# Winged         63
#              ...
# Lilac           1
# DanDayn         1
# shernfire       1
# Moojin          1
# Yampi           1
# Mess            1
# Yaelay          1
# Arcsecond       1
# Grigne          1
# Mister          1
# Akira           1
# Jcain           1
# Duxen           1
# Ever Ares       1
# Mowarth         1
# WTHeaven        1
# K3nSt3r         1
# Neiman          1
# WIND            1
# Dan             1
# Halpern         1
# Em1ya           1
# Hamezz          1
# MiMo            1
# Idyiom          1
# LEE             1
# TheFeeling      1
# Hana            1
# U Jun           1
# Shaunz          1
# Name: redJungle, Length: 349, dtype: int64
#
#
#
#
#
# redJungleChamp
# RekSai          1186
# Gragas          1099
# Elise            994
# LeeSin           789
# Graves           549
# Khazix           543
# JarvanIV         354
# Nidalee          329
# Sejuani          279
# Rengar           256
# Kindred          200
# Olaf             144
# Ivern            125
# Zac               94
# Evelynn           88
# Hecarim           83
# Maokai            72
# Nunu              70
# Ekko              49
# Vi                47
# Rumble            21
# Warwick           20
# Chogath           19
# Pantheon          17
# DrMundo           14
# Nocturne          13
# Poppy             13
# Shyvana           11
# Skarner           11
# Kayn              10
# Udyr              10
# Jax                7
# Ezreal             5
# XinZhao            5
# Trundle            5
# Rammus             5
# Camille            4
# Lulu               4
# Quinn              4
# Fizz               4
# Volibear           4
# MonkeyKing         3
# Nautilus           3
# MasterYi           2
# Malzahar           2
# Karma              2
# Jayce              2
# Rakan              1
# Amumu              1
# Aatrox             1
# Shaco              1
# Shen               1
# FiddleSticks       1
# Bard               1
# Riven              1
# MissFortune        1
# Sion               1
# Gnar               1
# Galio              1
# Name: redJungleChamp, dtype: int64
#
#
#
#
#
# redMiddle
# Faker            188
# Bjergsen         172
# Kuro             148
# Crown            143
# Maple            127
# Pobelter         127
# Ryu              126
# Febiven          123
# Mickey           122
# PowerOfEvil      119
# Keane            115
# Jensen           114
# Huhi             110
# Perkz            103
# Kuzan             98
# Frozen            98
# Naru              98
# GBM               92
# Exileh            90
# Tempt             88
# Froggen           87
# Betsy             85
# Sencux            84
# Ian               78
# Edge              78
# FoFo              77
# Fly               77
# Apex              76
# Ninja             74
# Coco              72
#                 ...
# Baxauer            1
# Shiage             1
# S Ysera            1
# Gears              1
# Glup               1
# Leonard            1
# NasesUyno          1
# Jinsh              1
# Shernfire          1
# Dumbledoge         1
# Environmental      1
# Flezeth            1
# do it              1
# Easy               1
# SorenXD            1
# Emp                1
# BDD                1
# PAinEvil           1
# Tiridus            1
# Mueki              1
# Crow               1
# Misteryous         1
# Icon               1
# ShLaYa             1
# Heavenstrike       1
# Grace              1
# Praedyth           1
# Exosen             1
# Gluppy             1
# Ryavka             1
# Name: redMiddle, Length: 323, dtype: int64
#
#
#
#
#
# redMiddleChamp
# Orianna         671
# Viktor          592
# Corki           518
# Cassiopeia      507
# Syndra          461
# Leblanc         422
# Azir            398
# Taliyah         346
# Ahri            345
# Ryze            334
# Vladimir        235
# Kassadin        222
# Lissandra       199
# Lulu            193
# Zed             167
# TwistedFate     149
# Varus           144
# Jayce           138
# Zilean          120
# Ekko            119
# Karma           118
# Malzahar        110
# Galio           104
# Fizz             85
# Anivia           77
# Xerath           71
# Lucian           71
# Ezreal           67
# Lux              51
# Talon            50
#                ...
# Irelia            7
# JarvanIV          6
# Nidalee           4
# Hecarim           4
# Pantheon          3
# Jhin              3
# Fiddlesticks      3
# Nasus             2
# Malphite          2
# Heimerdinger      2
# Kennen            2
# Camille           2
# Fiora             2
# Sion              1
# Kindred           1
# Mordekaiser       1
# Brand             1
# Twitch            1
# Renekton          1
# Sona              1
# Alistar           1
# Gragas            1
# Riven             1
# MasterYi          1
# Nautilus          1
# Olaf              1
# Thresh            1
# Rumble            1
# Nocturne          1
# Zyra              1
# Name: redMiddleChamp, Length: 77, dtype: int64
#
#
#
#
#
# redADC
# Bang            208
# Arrow           160
# Sneaky          152
# PraY            149
# WildTurtle      143
# Sangyoon        132
# Apollo          126
# Doublelift      122
# Rekkles         121
# Stixxay         112
# Kramer          104
# Zven             99
# Ruler            98
# Piglet           94
# Zeitnot          91
# Steeelback       88
# Nuclear          87
# Pilot            86
# Kobbe            86
# Altec            85
# BeBe             83
# HolyPhoenix      83
# Dee              78
# AN               77
# Deft             76
# MaHa             73
# Breeze           73
# Hjarnan          71
# SSol             71
# Mash             70
#                ...
# Stierlitz         1
# Breaker           1
# Kkramer           1
# Lilv              1
# Rakin             1
# M17Dee            1
# K                 1
# Whitelotus        1
# Sayn              1
# Smlz              1
# I Am The IRS      1
# Znsho             1
# The Foxz          1
# Nono              1
# nororin           1
# Aiming            1
# Kz                1
# cop               1
# Hobbler           1
# SirAlphaQ         1
# Bomb              1
# Moopz             1
# DANDAN            1
# S Ysera           1
# ZeroZeroYon       1
# Sa1na             1
# Vincent           1
# Frost             1
# aphromoo          1
# Nymue             1
# Name: redADC, Length: 347, dtype: int64
#
#
#
#
#
# redADCChamp
# Sivir          880
# Ashe           809
# Lucian         786
# Jhin           691
# Ezreal         646
# Varus          643
# Kalista        602
# Caitlyn        539
# Tristana       414
# Corki          402
# Xayah          272
# KogMaw         261
# Twitch         142
# Jinx           136
# Vayne           99
# Graves          94
# Urgot           41
# MissFortune     36
# Draven          27
# Kennen          23
# Ziggs           22
# Kindred          4
# Jayce            2
# Karthus          1
# Lulu             1
# Quinn            1
# Nunu             1
# Taliyah          1
# Mordekaiser      1
# Thresh           1
# Janna            1
# Kled             1
# Teemo            1
# Viktor           1
# Name: redADCChamp, dtype: int64
#
#
#
#
#
# redSupport
# Wolf           195
# GorillA        155
# Hylissang      138
# aphromoo       131
# SnowFlower     128
# Olleh          123
# Chei           123
# Albis          106
# Xpecial        105
# Smoothie       105
# MadLife        104
# Adrian         104
# Biofrost       103
# Jay            101
# Hakuho          96
# Matt            90
# LemonNation     89
# Vander          88
# Dreamer         85
# mithy           85
# IgNar           83
# Pure            83
# Dumbledoge      83
# Key             80
# Max             79
# Mata            79
# Wraith          79
# Gate            74
# CoreJJ          74
# Mikyx           72
#               ...
# XD               1
# Targamas         1
# Indivisible      1
# Five             1
# Baby             1
# Rippii           1
# Joey             1
# Chunkyfresh      1
# Mallek           1
# Breaker          1
# Gorilla          1
# Lounet           1
# S RD             1
# Beni             1
# Straawbella      1
# Ever Key         1
# Bluz0r           1
# Angelas          1
# Sweetr           1
# lehends          1
# Ralara           1
# Tarky            1
# Altec            1
# S HoHotDoG       1
# Tierwulf         1
# Wei              1
# Blumigan         1
# WarL0cK          1
# Stuntopolis      1
# Vioreleeee       1
# Name: redSupport, Length: 342, dtype: int64
#
#
#
#
#
# redSupportChamp
# Braum           1023
# Thresh           967
# Alistar          851
# Karma            714
# Janna            450
# Lulu             361
# Zyra             351
# TahmKench        346
# Nami             324
# Bard             318
# Morgana          237
# Trundle          225
# Rakan            192
# Malzahar         191
# Nautilus         164
# Annie            151
# Taric            129
# Blitzcrank       113
# Leona             88
# MissFortune       88
# Soraka            66
# Shen              36
# Brand             25
# Sona              25
# Kennen            25
# Poppy             20
# Zilean            17
# Galio             15
# Gragas            11
# Veigar             9
# Camille            8
# Ornn               6
# Elise              3
# Syndra             3
# Fiddlesticks       3
# Lissandra          2
# Maokai             2
# Ziggs              2
# Kayle              2
# Malphite           2
# TwistedFate        2
# Lux                2
# Ashe               1
# Irelia             1
# Velkoz             1
# Kalista            1
# Udyr               1
# Rengar             1
# Vayne              1
# Ivern              1
# Sejuani            1
# Jinx               1
# Sion               1
# Kled               1
# Nunu               1
# Name: redSupportChamp, dtype: int64

# %% [raw]
# We can see that there are no null values as we already dropped all of them, and ther are 2 columns for each player, one for the player's username, and the other for the name of the champion he chose, it would be better if the names were grouped in less columns.

# %%
Players_LOL_df = Players_LOL_df[Players_LOL_df.duplicated() == False] # Removing duplicates

# %% [markdown]
# # Getting a baseline accuracy using a K-Nearest Neigbours model

# %%
X = pd.get_dummies(LOL.drop('bResult', axis=1)) # Setting all of the columns except the target as the features matrix
y = LOL.bResult
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42) # Splitting the data for modelling 
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)

# %%
print(knn.score(X_test, y_test))
print(cross_val_score(knn,X,y,cv=10).mean())

# %%
list_of_scores = []
for i in range(1,30,2):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    list_of_scores.append(knn.score(X_test, y_test))
Scores = {'N':list(range(1,30,2)),'score':list_of_scores}
Scores = pd.DataFrame(Scores)
Scores.plot(x='N',y="score")

# %% [markdown]
# # Sorting the champions and the usernames

# %% [markdown]
# ### Method #1  (Didn't actually use this method eventually)

# %%
bTop_champs = []
bJungle_champs = []
bMiddle_champs = []
bADC_champs = []
bSupport_champs = []

rTop_champs = []
rJungle_champs = []
rMiddle_champs = []
rADC_champs = []
rSupport_champs = []

CHAMPS = [bTop_champs, bJungle_champs, bMiddle_champs, bADC_champs,
          bSupport_champs, rTop_champs, rJungle_champs, rMiddle_champs,
          rADC_champs, rSupport_champs]

TEAMS = ['blueTopChamp', 'blueJungleChamp', 'blueMiddleChamp', 'blueADCChamp',
       'blueSupportChamp', 'redTopChamp', 'redJungleChamp', 'redMiddleChamp',
       'redADCChamp', 'redSupportChamp','blueTop',
       'blueJungle', 'blueMiddle', 'blueADC', 'blueSupport', 'redTop',
       'redJungle', 'redMiddle', 'redADC', 'redSupport']

All_b_teams=[]
for i in range(len(TEAMS)):
    for z in LOL[TEAMS[i]]:
        CHAMPS[i].append(z)
        Blue_Team = []
        for pl in CHAMPS[:5]:
            Blue_Team.append((''.join(pl)))
            All_b_teams.append(Blue_Team)

# %% [markdown]
# ### Method #2 (I used this method instead)

# %%
def Add_strings(x):
    z = ''
    for i in x:
        z+=i
        z+=' '
    return z
LOL['BlueTeam'] = LOL[['blueTopChamp', 'blueJungleChamp', 'blueMiddleChamp', 'blueADCChamp',
       'blueSupportChamp']].apply(Add_strings, axis=1)

LOL['RedTeam'] = LOL[['redTopChamp', 'redJungleChamp', 'redMiddleChamp',
       'redADCChamp', 'redSupportChamp']].apply(Add_strings, axis=1) # First defining a function then applying it

LOL = LOL.drop(TEAMS,axis=1) # Dropping the columns that I just merged

# %% [markdown]
# # Building scraping functions to scrape data

# %% [markdown]
# ## 1- Scraping more features for already existing players/champions

# %% [markdown]
# ### The maximum needed inputs for the functions:
# - Usernames
# - Region
# - Champions
# - League

# %% [markdown]
# #### Using the requests library.

# %%
# Importing the libraries
import requests
from bs4 import BeautifulSoup
import selenium

# %%
# Defining a function to scrape the data off the first website.

def GetSummonerStats(username, region):
    username = username.replace(' ', '+') # Preparing the username
    Summoner = requests.get('http://{}.op.gg/summoner/userName={}'.format(region, username)) 
    Summoner = BeautifulSoup(Summoner.text, 'html.parser') # Getting the html of the website

    # Extracting the wanted data
    Total_games = Summoner.findAll('div', attrs={'class':'WinRatioTitle'})
    if len(Total_games) == 0:
        return 'Not enough games to get stats'
    for i in Total_games[0]:
        i=str(i)
        if i.count('total') != 0:
            total = i
        elif i.count('win') != 0:
            wins = i
        elif i.count('lose') != 0:
            losses = i
    total = int(total[20:24].replace('<','').replace('/','').replace('s','').replace('p','').replace('>',''))
    wins = int(wins[18:23].replace('<','').replace('/','').replace('s','').replace('p','').replace('>',''))
    losses = int(losses[18:23].replace('<','').replace('/','').replace('s','').replace('p','').replace('>',''))
    try:
        if int(total) < 10:
            return 'Not enough games to get stats'
        else:
            pass
    except:
        pass

    WinRate = list(Summoner.findAll('div', attrs={"class":"Text"}))
    for i,v in enumerate(WinRate):
        WinRate[i] = str(WinRate[i])  
    WinRate = WinRate[-1][18:22]
    WinRate = int(WinRate.replace('%','').replace('<',''))
    
    return total,wins,losses,WinRate

# %%
GetSummonerStats('steyex', 'euw')
# total, wins, losses, win rate

# %% [markdown]
# #### Using Selenuim

# %%
from selenium import webdriver # Importing selenium

# Defining 3 functions to scrape the data off the second website using selenuim instead.

# A function to scrape the summoner's statistics
def Get_S_Stats(username, region='euw'): 
    username = username.replace(' ','+')
    chrome_options = webdriver.ChromeOptions()
    chrome_options.add_argument('--headless')
    chrome_options.add_argument('--no-sandbox')
    driver = webdriver.Chrome(executable_path='./chromedriver/chromedriver',chrome_options=chrome_options,
  service_args=['--verbose', '--log-path=/tmp/chromedriver.log'])    
    driver.get(f"https://www.leagueofgraphs.com/summoner/{region}/{username}")
    elem = driver.find_element_by_id("mainContent")
    stats = []
    for i in range(10):
        try:
            stats.append(int(elem.find_elements_by_class_name("pie-chart")[i].text))
        except:
            try:
                stats.append(float(elem.find_elements_by_class_name("pie-chart")[i].text[:-1]))
            except:
                pass
    driver.close()
    try:
        if stats[0] > 9:
            return stats
        else:
            return stats
    except:
        return 'Not enough games'

# A function to scrape the summoner's statistics specific to one champion
def Get_SC_Stats(username, champion, region='euw'): 
    username = username.replace(' ','+')
    champion = champion.lower().replace('.','').replace("'",'').replace(' ','')
    chrome_options = webdriver.ChromeOptions()
    chrome_options.add_argument('--headless')
    chrome_options.add_argument('--no-sandbox')
    driver = webdriver.Chrome(executable_path='./chromedriver/chromedriver',chrome_options=chrome_options,
  service_args=['--verbose', '--log-path=/tmp/chromedriver.log'])    
    driver.get(f"https://www.leagueofgraphs.com/summoner/performance/{champion}/{region}/{username}")
    elem = driver.find_element_by_id("mainContent")
    stats = []
    for i in range(10):
        try:
            stats.append(int(elem.find_elements_by_class_name("pie-chart")[i].text))
        except:
            try:
                stats.append(float(elem.find_elements_by_class_name("pie-chart")[i].text[:-1]))
            except:
                pass
    driver.close()
    try:
        if stats[0] > 9:
            return stats
        else:
            return stats
    except:
        return 'Not enough games'

# A function to scrape the champion's statistics
def Get_C_Stats(champion):
    champion = champion.lower().replace('.','').replace("'",'').replace(' ','')
    chrome_options = webdriver.ChromeOptions()
    chrome_options.add_argument('--headless')
    driver = webdriver.Chrome(executable_path='./chromedriver/chromedriver',chrome_options=chrome_options,
  service_args=['--verbose', '--log-path=/tmp/chromedriver.log'])
    driver.get(f"https://www.leagueofgraphs.com/champions/stats/{champion}")
    elem = driver.find_element_by_id("mainContent")
    stats = []
    for i in range(10):
        try:
            stats.append(int(elem.find_elements_by_class_name("pie-chart")[i].text))
        except:
            try:
                stats.append(float(elem.find_elements_by_class_name("pie-chart")[i].text[:-1]))
            except:
                pass
    driver.close()
    return stats


print(Get_SC_Stats('riv rodus', 'Lux'))  # [Games Played, Winrate]
print(Get_C_Stats('Lux'))                # [Popularity, Winrate, BanRate, Mained by]
# Out:
# Not enough games
# [12.0, 51.1, 1.2, 1.8]

# %% [markdown]
# ## 2- Scraping new players/champions

# %%
# Scraping new usernames from the website

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
driver = webdriver.Chrome(executable_path='./chromedriver/chromedriver',chrome_options=chrome_options,
service_args=['--verbose', '--log-path=/tmp/chromedriver.log'])    
driver.get('https://www.leagueofgraphs.com/rankings/summoners/euw')
elem = driver.find_element_by_id("mainContent")

New_players = []

for i in elem.find_elements_by_class_name("large-16")[0].find_elements_by_class_name('box'
)[0].find_elements_by_class_name('data_table')[0].find_elements_by_class_name('name'):
    New_players.append(Get_S_Stats(i.text))

driver.quit()

# %%
len(New_players)
# Out:
# 69

# %%
New_players[-5:] # [Games Played, Winrate]
# Out:
# [[1160, 54.5], [384, 65.6], [861, 55.7], [1589, 54.1], [2196, 52.0]]

# %%
# Zipping each player's username to their champion

x,y = LOL['redTop'],LOL['redTopChamp']
X = []
Y = []
for i in x:
    X.append(i)
for i in y:
    Y.append(i)
LOL['RedTop'] = list(zip(X,Y))

x,y = LOL['redJungle'],LOL['redJungleChamp']
X = []
Y = []
for i in x:
    X.append(i)
for i in y:
    Y.append(i)
LOL['RedJungle'] = list(zip(X,Y))

x,y = LOL['redMiddle'],LOL['redMiddleChamp']
X = []
Y = []
for i in x:
    X.append(i)
for i in y:
    Y.append(i)
LOL['RedMiddle'] = list(zip(X,Y))


x,y = LOL['redADC'],LOL['redADCChamp']
X = []
Y = []
for i in x:
    X.append(i)
for i in y:
    Y.append(i)
LOL['RedADC'] = list(zip(X,Y))

x,y = LOL['redSupport'],LOL['redSupport']
X = []
Y = []
for i in x:
    X.append(i)
for i in y:
    Y.append(i)
LOL['RedSupport'] = list(zip(X,Y))

x,y = LOL['blueTop'],LOL['blueTopChamp']
X = []
Y = []
for i in x:
    X.append(i)
for i in y:
    Y.append(i)
LOL['BlueTop'] = list(zip(X,Y))

x,y = LOL['blueJungle'],LOL['blueJungleChamp']
X = []
Y = []
for i in x:
    X.append(i)
for i in y:
    Y.append(i)
LOL['BlueJungle'] = list(zip(X,Y))

x,y = LOL['blueMiddle'],LOL['blueMiddleChamp']
X = []
Y = []
for i in x:
    X.append(i)
for i in y:
    Y.append(i)
LOL['BlueMiddle'] = list(zip(X,Y))

x,y = LOL['blueADC'],LOL['blueADCChamp']
X = []
Y = []
for i in x:
    X.append(i)
for i in y:
    Y.append(i)
LOL['BlueADC'] = list(zip(X,Y))

x,y = LOL['blueSupport'],LOL['blueSupportChamp']
X = []
Y = []
for i in x:
    X.append(i)
for i in y:
    Y.append(i)
LOL['BlueSupport'] = list(zip(X,Y))

# %%
LOL = LOL.drop(TEAMS,axis=1) # Dropping the individual columns for the usernames and champions

# %%
for i in LOL['RedTop']:
    print(Get_C_Stats(i[1]),i)
    break

# [2.7, 46.3, 0.6, 0.2] ('Balls', 'Gnar')
# Out:
# [2.6, 46.1, 0.6, 0.1] ('Balls', 'Gnar')

# %% [markdown]
# ### Data engineering the newly scraped data

# %%
from functools import reduce
New_players_list2 = []
for i in New_players_list:
    x = reduce(lambda x, y: x + y, i) / len(i)
    New_players_list2.append(x)

# %%
sorted(New_players_list2) # Checking the average
# Out:
# [53.17999999999999,
#  53.52,
#  53.96,
#  54.28000000000001,
#  54.580000000000005,
#  55.05999999999999,
#  55.31999999999999,
#  55.52,
#  55.739999999999995,
#  56.32000000000001,
#  57.44,
#  58.720000000000006]
